# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from StabilityExperiment import StabilityExperiment

plt.rcParams['figure.dpi'] = 300

test = StabilityExperiment('stability_test_1.xls', start_spectrum = 4, wavelength_ranges = {'blue':(420,470), 'red':(600,730)})

test.get_pl_time()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
#     elapsed time (h)  stability_test_1_blue  stability_test_1_red
# 5           0.000000               1.000000              1.000000
# 6           0.083333               0.979882              0.992666
# 7           0.166667               0.997762              0.981997
# 8           0.241389               0.999950              0.981270
# 9           0.741389               0.986396              0.944732
# 10          1.241389               0.990753              0.936662
# 11          1.741389               0.960832              0.927889
# 12          2.241389               0.986845              0.919558
# 13          2.741389               0.975415              0.904946
# 14          3.241389               1.002591              0.899611
# 15          4.414167               1.015632              0.897595
# 16          7.414167               0.996245              0.878309
# ...

# %%
test.plot_pl()

# %%
test.plot_stretched('red',100)
# Out:
# stability_test_1_red
# Stretched exponential has been fitted!
