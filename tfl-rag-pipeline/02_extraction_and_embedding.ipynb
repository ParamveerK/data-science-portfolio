# %%
import json
import pdfplumber

try:
    with open('data/web_data.json', 'r') as f:
        project_data = json.load(f)
except FileNotFoundError:
    raise SystemExit('data/web_data.json not found, run the scraping notebook first!')

test_project = project_data['walking-and-cycling-changes-oval-elephant-and-castle']
document_text_pdf = []
for document in test_project['documents']:
    with pdfplumber.open(document) as pdf:
        for page in pdf.pages:
            text = page.extract_text_simple()
            document_text_pdf.append(text)

document_text_pdf[:5]
# Out:
# ['D\nA\nO\nR\nE\nG\nD\nRI\nB\nT\nARK TREE\nW S\nSOUTH GH\nHI\nH\nBAYLISROADWATERLOOROAD BLACKFRIARSROAD GREATSUFFOLK STREET BOROUG LONG\nLANE\nSRitver ThHames.Ca oTshnhMpBoETiHdmt a PAaLaA lCnEsK  R’OgAeDenAsrnc hoPibnainsrkhgo Ntp’osenw  PRiOnaADrgkt oRno aBdRuOADKENtNINGTtONs WLAEMSTBMETIHN S   ILT W oERnROM dA BoDRnSCSIDtoSa.GTut .GhE t Gh ee ERwdoODrrRaagrGlekE’s’S  ROADLONDON  ROADBOROUGH    NN EE WWRIINNOGGTTAOONND    CCAAUUSSEEWWAAYY HARTPRERIN  RIOTAYD  ST GREATDOVERSTREET\nLA LAMBETH  BROOK  DRIVE The CaOSWsIN  STtle ElephCaanstt l&e NEW  KENT  ROAD\nALBERTEMBANKMENT DAOR  NOTGNINNEK LeiDsANuTrEe  RC OCSAhteDu.n rMtcrhaeryyaN’ErsWdINGTON  BUSTT WALWORTH  R HEYGATE  ST RROOADDNEY\nO\nBLACK  PRINCE  ROAD KENNINGTONO  LCTALHNOEESLLEO PEN AD\nHXUAV Poaf rSisth.  MCahruyTrOcNh  PLACE\nHARLEYFOSTRDUDRHA M ROAKDENALLN  STRIEENTGTVOAUXNHALL   S TLKAENNNEINGTON NNIENKGTON ROAPDostRACSVKETiENtARNNoyINEr fSG&tE TDL OT SNoGO c PnNuAhRdPiKol Ao KdRoOEnRsAKlNDKE N NPWINLNAGAICTNYEOGNS BRAGANZKAe  SnTRnEiEnTgton MANOR  PLACE WALWORTH  ROEAADST  STREET PORTLANDSTREET ALBANYROAD\nPASRTRY KENN GCOrroicvukaneldt   OVAL MAGOEEffice Kennington COOK’S  ROA\nVaPuaxrhkall HIANGRTLOESYNTFR O OEROEVDTAvLal ST Park D USKIN  STREET\nFENTIMAN  ROAD SCth. uMrcahrkD’sCAMBERWELL  NEW JOHN  R CAMBERWELL\nM  ROAD N  ROA   ROAD   ROAD\nAPHA RIXTO\nCL B\nS\nO\nUTH LAMBETH  ROA Key VASSALL  ROPAATMDOS  ROA LOTHIAN  ROCADAMBERWELL  NEW  ROAD MMEEDDLLAARR    SSTT\nD D\nNew section of bus lane (operating 24hr)\nD\nA\nO\nR\nLANSDOWNE WAY Existing section of 24hr bus lane ERMAN   CAMBERSWTREELLETCHURCH\nK\nContains Ordnance Survey data A\n© Crown copyright 2021',
#  'Have your say about TfL’s new \nroad schemes to help people \nwalk and cycle more',
#  'What’s inside? \n \nWhy does TfL want \nPage 5 \nyour feedback \n \nWhat does TfL want \nPage 7 \nto find out? \nChecking the road \nPage 15 \nchanges \n \nHow does TfL decide \nif the changes are a  Page 17 \nsuccess? \n \nHow could the road \nscheme change  Page 29 \nthings? \n \n   \n \n ',
#  ' \nWelcome \nIn May 2020 TfL carried out \nemergency work because of \n  COVID-19. \nTfL made some changes to the \nroads around London to help \nmore people walk and cycle in \ntheir local area. \n \n \nNow TfL wants to find out \nwhat you think about the \nchanges on the road.  \n \nTfL still needs to change more \nroads very quickly. \nPage 3 of 36 \n ',
#  ' \nWe want to find out what is \ngood and bad about the \nchanges so we are going to \nask: \n \n● local people \n \n● local businesses \n \n● local groups. \nPage 4 of 36 \n ']

# %%
from docx import Document

test_project = project_data['30-205-bus-proposals']
document_text_docx = []
for document in test_project['documents']:
    if document.split('.')[-1] == 'docx':
        doc = Document(document)
        for paragraph in doc.paragraphs:
            document_text_docx.append(paragraph.text)
        
document_text_docx[:5]
# Out:
# ['Proposed changes to bus routes 30 and 205',
#  '',
#  'Tell us your views',
#  'We are holding a six week public consultation to hear what you think about these proposals. We want to know if you agree with them, if there is anything you do not agree with, and to understand the reasons why you feel this way.',
#  '']

# %%
try:
    with open('data/text_data.json', 'r') as f:
            project_data = json.load(f)
except:
    print('no text_data.json found, searching for web_data.json instead...')
    try:
        with open('data/web_data.json', 'r') as f:
            project_data = json.load(f)
    except:
        print('no web_data.json found, run the scraping notebook first!')
        pass



for pname, pdata in project_data.items():
    if 'doc_texts' in pdata and pdata['doc_texts']:
        print(f'doc_texts found for {pname}, skipping...')
        continue
    project_data[pname]['doc_texts'] = []
    for document in pdata['documents']:
        ext = document.split('.')[-1]
        try:
            if ext == 'pdf':
                with pdfplumber.open(document) as pdf:
                    doc_text_pdf = ''
                    for page in pdf.pages:
                        text = page.extract_text_simple()
                        doc_text_pdf += text
                project_data[pname]['doc_texts'].append(doc_text_pdf)
            elif ext == 'docx':
                doc = Document(document)
                text = '\n'.join(p.text for p in doc.paragraphs if p.text.strip())
                project_data[pname]['doc_texts'].append(text)
            print(f'converted {ext} text for {document}')
        except:
            continue

    with open('data/text_data.json','w') as f:
        json.dump(project_data,f)
    
with open('data/text_data.json','w') as f:
    json.dump(project_data,f)
print('text data saved under data/text_data.json')
# Out:
# doc_texts found for lowering-speed-limits, skipping...
# doc_texts found for bus-routes-287-687, skipping...
# doc_texts found for merantun-way, skipping...
# doc_texts found for a232-healthy-streets, skipping...
# doc_texts found for earls-court-road-works, skipping...
# doc_texts found for lsa, skipping...
# doc_texts found for congestion-charge-proposals, skipping...
# doc_texts found for bilton-way, skipping...
# doc_texts found for a21-hastings-road, skipping...
# doc_texts found for superloop-expansion, skipping...
# doc_texts found for cycleway-c62, skipping...
# doc_texts found for bl1-superloop, skipping...
# doc_texts found for 654-bus-route, skipping...
# doc_texts found for east-putney-improvements, skipping...
# doc_texts found for 319-weekend-night-service, skipping...
# doc_texts found for shoreditch, skipping...
# doc_texts found for bus-routes-346-347-497, skipping...
# doc_texts found for crossing-stonecot-hill, skipping...
# doc_texts found for a24-morden-road, skipping...
# doc_texts found for a21-bromley-road, skipping...
# doc_texts found for route-224, skipping...
# doc_texts found for 30-205-bus-proposals, skipping...
# doc_texts found for tulse-hill-safety-scheme, skipping...
# doc_texts found for portland-avenue, skipping...
# doc_texts found for hogarth-roundabout, skipping...
# doc_texts found for godstone-road-pedestrian-crossing, skipping...
# doc_texts found for route-241-extension, skipping...
# doc_texts found for c50-finsbury-park-nags-head, skipping...
# doc_texts found for route-281-extension, skipping...
# doc_texts found for lower-lea-crossing, skipping...
# doc_texts found for hounslow-brentford-walking-and-cycling-changes, skipping...
# doc_texts found for gracefield-gardens, skipping...
# doc_texts found for sustainable-development-framework, skipping...
# doc_texts found for taxi-fares-2021, skipping...
# doc_texts found for routes-1-168-188, skipping...
# doc_texts found for routes-21-143-263-271, skipping...
# doc_texts found for a102-noise-barrier, skipping...
# doc_texts found for london-bridge-corridor, skipping...
# doc_texts found for borough-high-street, skipping...
# doc_texts found for balham-clapham, skipping...
# doc_texts found for waterloo-road-pavement-widening, skipping...
# doc_texts found for euston-road, skipping...
# doc_texts found for south-newham-bus-changes, skipping...
# doc_texts found for streatham-high-road, skipping...
# doc_texts found for brixton-town-centre, skipping...
# doc_texts found for dalston-kingsland-road, skipping...
# doc_texts found for access-our-older-consultations, skipping...
# doc_texts found for finchley-road, skipping...
# doc_texts found for greenwich-to-woolwich-section-2, skipping...
# doc_texts found for 1new-kent-road-bus-lane-trial, skipping...
# doc_texts found for tower-bridge-road-bus-lane-trial, skipping...
# doc_texts found for hatch-lane-route-changes, skipping...
# doc_texts found for all-day-bus-lanes-trial, skipping...
# doc_texts found for in-vehicle-cctv, skipping...
# doc_texts found for london-service-permit-consultations, skipping...
# doc_texts found for bus-route-497, skipping...
# doc_texts found for bus-route-410, skipping...
# doc_texts found for routes-n21-n550-n551, skipping...
# doc_texts found for earls-court-road, skipping...
# doc_texts found for penalty-charge-2021, skipping...
# doc_texts found for congestion-charge-changes, skipping...
# doc_texts found for how-we-involve-you-faqs, skipping...
# doc_texts found for bus-route-r7, skipping...
# doc_texts found for camden-road-toucan-crossing-scheme, skipping...
# doc_texts found for lowering-speeds-westminster, skipping...
# doc_texts found for bus-route-633, skipping...
# doc_texts found for walking-and-cycling-changes-chelsea-bridge-wandsworth-town, skipping...
# doc_texts found for lumley-road, skipping...
# doc_texts found for pavement-widening-west-wickham, skipping...
# doc_texts found for walking-and-cycling-changes-on-tooley-street, skipping...
# doc_texts found for walking-and-cycling-changes-oval-streatham, skipping...
# doc_texts found for walking-and-cycling-changes-oval-elephant-and-castle, skipping...
# text data saved under data/text_data.json

# %%
import pandas as pd
import matplotlib.pyplot as plt

pnames = []
doc_names = []
doc_lengths = []
doc_texts = []
for pname, pdata in project_data.items():
    pnames.append(pname)
    doc_names.append(f'{pname}-text')
    doc_texts.append(pdata['project_text'])
    doc_length = len(pdata['project_text'])
    doc_lengths.append(doc_length)
    for i, document in enumerate(pdata['doc_texts']):    
        doc_name = pdata['documents'][i].split('/')[-1]
        pnames.append(pname)
        doc_names.append(doc_name)
        doc_length = len(document.split())
        doc_lengths.append(doc_length)
        doc_texts.append(pdata['doc_texts'][i])
    

doc_df = pd.DataFrame({'project':pnames,'document':doc_names,'doc_length':doc_lengths, 'doc_text':doc_texts})
print(doc_df.head(20))
# Out:
#                          project                           document  \
# 0          lowering-speed-limits         lowering-speed-limits-text
# 1          lowering-speed-limits       lowering-speed-limits_0.html
# 2          lowering-speed-limits        lowering-speed-limits_1.pdf
# 3                   capital-call                  capital-call-text
# 4        youth-panel-application       youth-panel-application-text
# 5             bus-routes-287-687            bus-routes-287-687-text
# 6             bus-routes-287-687           bus-routes-287-687_0.pdf
# 7             bus-routes-287-687          bus-routes-287-687_1.docx
# 8             bus-routes-287-687           bus-routes-287-687_2.pdf
# 9             bus-routes-287-687          bus-routes-287-687_3.docx
# 10                 673-bus-route                 673-bus-route-text
# 11               a1-archway-road               a1-archway-road-text
# 12     a10-lincoln-road-junction     a10-lincoln-road-junction-text
# 13                  merantun-way                  merantun-way-text
# 14                  merantun-way                 merantun-way_0.pdf
# 15        310-holloway-nags-head        310-holloway-nags-head-text
# 16            meridian-water-bus            meridian-water-bus-text
# 17  dlr-extension-consultation-2  dlr-extension-consultation-2-text
# 18            routes-259-279-349            routes-259-279-349-text
# 19              bus-routes-19-38              bus-routes-19-38-text
#
#     doc_length                                           doc_text
# 0        10432  \n\n\n\n\n\n\nCustom\n\n\n\n\n\n\n\nType of co...
# 1         7474  Safe speeds for central London – \nintroducing...
# 2          205  Equalities Statement \nWe are subject to the g...
# 3        21737  \n\n\n\n\n\n\nCustom\n\n\n\n\n\n\n\nType of co...
# 4         8782  \n\n\n\n\n\n\nWho's Listening\n\n\n\n\n\n\n\n\...
# 5        30091  \n\n\n\n\n\n\nPhotos\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 6        16786   \n \n287 and 687 – proposed changes to \n \nb...
# 7         5543  Contents\t\n1. Executive Summary\t1\n1.1\tNext...
# 8        10723  Title: Customer Equality Impact Assessment (EQ...
# 9          524  Customer Equality Impact Assessment (EQIA) For...
# 10       11250  \n\n\n\n\n\n\nCustom\n\n\n\n\n\n\n\nType of co...
# 11       18725  \n\n\n\n\n\n\nCustom\n\n\n\n\n\n\n\nType of co...
# 12       23340  \n\n\n\n\n\n\nCustom\n\n\n\n\n\n\n\nType of co...
# 13        7740  \n\n\n\n\n\n\nCustom\n\n\n\n\n\n\n\nType of co...
# 14         155  A24 Merantun Way/Station Road Crossing\n38a 40...
# 15       13969  \n\n\n\n\n\n\nCustom\n\n\n\n\n\n\n\nType of co...
# 16       21509  \n\n\n\n\n\n\nCustom\n\n\n\n\n\n\n\nType of co...
# 17       37383  \n\n\n\n\n\n\nCustom\n\n\n\n\n\n\n\nType of co...
# 18       17281  \n\n\n\n\n\n\nCustom\n\n\n\n\n\n\n\nType of co...
# 19       20679  \n\n\n\n\n\n\nCustom\n\n\n\n\n\n\n\nType of co...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=500,chunk_overlap=10)

doc_df['doc_chunks'] = doc_df['doc_text'].apply(lambda x: text_splitter.split_text(x))
doc_df['num_chunks'] = doc_df['doc_chunks'].apply(len)

# %%
doc_df = doc_df[doc_df['num_chunks'] > 0]
doc_df['num_chunks'].describe()
# Out:
# count    1453.000000
# mean       50.734343
# std       108.860475
# min         1.000000
# 25%         6.000000
# 50%        19.000000
# 75%        50.000000
# max      1438.000000
# Name: num_chunks, dtype: float64

# %%
chunks_df = doc_df.explode('doc_chunks')
chunks_df.head()
# Out:
#                  project                    document  doc_length  \
# 0  lowering-speed-limits  lowering-speed-limits-text       10432
# 0  lowering-speed-limits  lowering-speed-limits-text       10432
# 0  lowering-speed-limits  lowering-speed-limits-text       10432
# 0  lowering-speed-limits  lowering-speed-limits-text       10432
# 0  lowering-speed-limits  lowering-speed-limits-text       10432
#
#                                             doc_text  \
# 0  \n\n\n\n\n\n\nCustom\n\n\n\n\n\n\n\nType of co...
# 0  \n\n\n\n\n\n\nCustom\n\n\n\n\n\n\n\nType of co...
# 0  \n\n\n\n\n\n\nCustom\n\n\n\n\n\n\n\nType of co...
# 0  \n\n\n\n\n\n\nCustom\n\n\n\n\n\n\n\nType of co...
# 0  \n\n\n\n\n\n\nCustom\n\n\n\n\n\n\n\nType of co...
#
#                                           doc_chunks  num_chunks
# 0  Custom\n\n\n\n\n\n\n\nType of conversation:\nI...          28
# 0  Safe Speeds\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nF...          28
# 0  Chloe Rodgers\n\n\n\n\n\n\n\n\nLocal Communiti...          28
# 0  Share Lowering Speed Limits Programme on Faceb...          28
# 0  The Mayor and Transport for London (TfL) are c...          28

# %%
from sentence_transformers import SentenceTransformer
import os
import uuid

if os.path.exists('data/embedded_chunks_df.pkl'):
    embedded_chunks_df = pd.read_pickle('data/embedded_chunks_df.pkl')
else:
    model = SentenceTransformer('all-MiniLM-L6-v2')
    embeddings = model.encode(chunks_df['doc_chunks'].tolist(), show_progress_bar=True)
    embedded_chunks_df = chunks_df.copy()
    embedded_chunks_df['embeddings'] = list(embeddings)
    embedded_chunks_df = embedded_chunks_df.drop_duplicates(subset=['doc_chunks'], keep='first')
    embedded_chunks_df['uuid'] = embedded_chunks_df.apply(lambda _: str(uuid.uuid1()), axis=1)

    embedded_chunks_df.to_pickle('data/embedded_chunks_df.pkl')
# Out:
# Batches:   0%|          | 0/2304 [00:00<?, ?it/s]
